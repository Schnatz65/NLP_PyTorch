# %% [markdown]
# # Korpuse laden

# %%
import subprocess
import os, stat

os.chmod('./data/distribute-all-data.sh', stat.S_IRWXU)
exit_code = subprocess.call('./data/distribute-all-data.sh')
print(exit_code)
